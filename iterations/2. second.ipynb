# %% [markdown]
# ### Second Iter (05 May)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_df =  pd.read_csv('data/train.csv', index_col='PassengerId')
train_df
