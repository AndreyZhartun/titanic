# %% [markdown]
# ### main.py через jupyter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from config import config
from utils import set_seed

# %%
set_seed(config.general.seed)

# %%
full_df = pd.read_csv(config.paths.train, index_col='PassengerId')
full_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(
    full_df, 
    test_size=config.split.test_size,
    random_state=config.general.seed, 
    shuffle=config.split.shuffle
)

# %% [markdown]
# First Iteration Preprocessing

# %%
from preprocessing import preprocess

df = preprocess(train_df)
df
# df.describe()
# Out:
#              Survived  Pclass Sex  SibSp  Parch  Family_Size  Alone  \
# PassengerId
# 332                 0       1   0      0      0            0      1
# 734                 0       2   0      0      0            0      1
# 383                 0       3   0      0      0            0      1
# 705                 0       3   0      1      0            1      0
# 814                 0       3   1      4      2            6      0
# ...               ...     ...  ..    ...    ...          ...    ...
# 107                 1       3   1      0      0            0      1
# 271                 0       1   0      0      0            0      1
# 861                 0       3   0      2      0            2      0
# 436                 1       1   1      1      2            3      0
# 103                 0       1   0      0      1            1      0
#
#              Embarked_C  Embarked_S Age_Group Fare_Range
# PassengerId
# 332                 0.0         1.0         2          2
# ...

# %%
from linear import Linear

# logreg
linear = Linear(df, penalty='l2')

linear.cv()
# Out:
# x:\DSML\Miniconda\envs\titanic\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# x:\DSML\Miniconda\envs\titanic\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# ...

# %%
logreg_l1 = Linear(df, penalty='l1')

logreg_l1.cv()
# Out:
# x:\DSML\Miniconda\envs\titanic\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 ridge = Linear(df, penalty='l1')
# ----> 3 ridge.cv()
#
# File x:\DSML\titanic\linear.py:51, in cv(self)
#      48 train_X = scaler.fit_transform(train_X)
#      49 train_X = train_X.to_numpy()
# ---> 51 train_y = self.y.iloc[train_index].to_numpy()
#      53 fitted = self.model.fit(train_X, train_y)
#      55 # test
#
# ...
