# %% [markdown]
# ## Титаник
# ### main.py через jupyter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from ml_pipeline.base.utils import set_seed

from ml_pipeline.classification.config import classification_config as config
from ml_pipeline.classification.pipeline import ClassificationPipeline

set_seed(config.general.seed)

def boxplot(results: list, labels: list | None = None):
    data = []

    for item in results:
        data.append([x["score"] for x in item["fold_data"]])

    plt.boxplot(data, tick_labels=labels)
    plt.show()

# %% [markdown]
# Полный пайплайн

# %%
pipeline = ClassificationPipeline()

# %%
pipeline.run()
# Out:
# Running (0): dummy with {'strategy': 'most_frequent'}
# Fold 1/5 accuracy: 0.6145
# Fold 2/5 accuracy: 0.6180
# Fold 3/5 accuracy: 0.6180
# Fold 4/5 accuracy: 0.6180
# Fold 5/5 accuracy: 0.6124
# -> Best fold: 2, CV accuracy: 0.6162, std: 0.0023
#
# Running (1): logistic_regression with {'l1_ratio': 0, 'solver': 'lbfgs', 'max_iter': 500}
# Fold 1/5 accuracy: 0.7933
# Fold 2/5 accuracy: 0.8090
# Fold 3/5 accuracy: 0.7921
# Fold 4/5 accuracy: 0.8146
# Fold 5/5 accuracy: 0.8258
# -> Best fold: 5, CV accuracy: 0.8070, std: 0.0129
#
# Running (2): knn with {'n_neighbors': 3}
# Fold 1/5 accuracy: 0.8380
# Fold 2/5 accuracy: 0.6629
# Fold 3/5 accuracy: 0.7303
# Fold 4/5 accuracy: 0.7978
# Fold 5/5 accuracy: 0.7584
# -> Best fold: 1, CV accuracy: 0.7575, std: 0.0596
#
# Running (3): decision_tree with {'random_state': 42, 'min_samples_leaf': 4}
# Fold 1/5 accuracy: 0.8324
# Fold 2/5 accuracy: 0.7472
# Fold 3/5 accuracy: 0.8090
# Fold 4/5 accuracy: 0.7809
# Fold 5/5 accuracy: 0.7865
# -> Best fold: 1, CV accuracy: 0.7912, std: 0.0286
#
# Running (4): random_forest with {'n_estimators': 700, 'max_depth': 3, 'random_state': 42}
# Fold 1/5 accuracy: 0.8268
# Fold 2/5 accuracy: 0.8146
# Fold 3/5 accuracy: 0.7921
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8539
# -> Best fold: 5, CV accuracy: 0.8182, std: 0.0213
#
# Running (5): catboost with {'iterations': 300, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8101
# Fold 2/5 accuracy: 0.8258
# Fold 3/5 accuracy: 0.7978
# Fold 4/5 accuracy: 0.8258
# Fold 5/5 accuracy: 0.7753
# -> Best fold: 2, CV accuracy: 0.8070, std: 0.0190
#
# Running (6): lightgbm with {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/5 accuracy: 0.7933
# Fold 2/5 accuracy: 0.7584
# Fold 3/5 accuracy: 0.7809
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8315
# -> Best fold: 5, CV accuracy: 0.7935, std: 0.0242
#
# Running (7): xgboost with {'n_estimators': 300, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8380
# Fold 2/5 accuracy: 0.7865
# Fold 3/5 accuracy: 0.7584
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8034
# -> Best fold: 1, CV accuracy: 0.7979, std: 0.0259
#
# Running (8): dnn with {'in_features': 12, 'hidden_sizes': [128, 64], 'out_features': 2, 'dropout_rate': 0.25, 'batch_size': 16, 'test_size': 0.2, 'epochs': 100, 'learning_rate': 0.001, 'epochs_patience': 10, 'best_loss_threshold_to_save': 0.001, 'random_state': 42, 'save_dir': 'pytorch_models'}
# Epoch #0/100 ended: mean_train_loss=0.5823, running_train_acc=0.7053, mean_val_loss=0.4398, running_val_acc=0.8451
# epoch 1: saved model with loss 0.4295724630355835
# Epoch #1/100 ended: mean_train_loss=0.4918, running_train_acc=0.7737, mean_val_loss=0.4296, running_val_acc=0.8239
# epoch 2: saved model with loss 0.41395844684706795
# Epoch #2/100 ended: mean_train_loss=0.4801, running_train_acc=0.7947, mean_val_loss=0.4140, running_val_acc=0.8310
# Epoch #3/100 ended: mean_train_loss=0.4804, running_train_acc=0.8088, mean_val_loss=0.4348, running_val_acc=0.8239
# Epoch #4/100 ended: mean_train_loss=0.4472, running_train_acc=0.8070, mean_val_loss=0.4182, running_val_acc=0.8239
# Epoch #5/100 ended: mean_train_loss=0.4736, running_train_acc=0.7860, mean_val_loss=0.4189, running_val_acc=0.8310
# Epoch #6/100 ended: mean_train_loss=0.4653, running_train_acc=0.7947, mean_val_loss=0.4373, running_val_acc=0.8239
# Epoch #7/100 ended: mean_train_loss=0.4383, running_train_acc=0.8316, mean_val_loss=0.4474, running_val_acc=0.8169
# Epoch #8/100 ended: mean_train_loss=0.4575, running_train_acc=0.8140, mean_val_loss=0.4491, running_val_acc=0.8099
# Epoch #9/100 ended: mean_train_loss=0.4301, running_train_acc=0.8070, mean_val_loss=0.4380, running_val_acc=0.8310
# Epoch #10/100 ended: mean_train_loss=0.4367, running_train_acc=0.8193, mean_val_loss=0.4335, running_val_acc=0.8239
# Epoch #11/100 ended: mean_train_loss=0.4518, running_train_acc=0.8105, mean_val_loss=0.4314, running_val_acc=0.8239
# Epoch #12/100 ended: mean_train_loss=0.4407, running_train_acc=0.8193, mean_val_loss=0.4324, running_val_acc=0.8239
# Breaking on epoch 12; loaded best loss model from file
# Fold 1/5 accuracy: 0.7877
# Epoch #0/100 ended: mean_train_loss=0.5736, running_train_acc=0.7023, mean_val_loss=0.4857, running_val_acc=0.8310
# epoch 1: saved model with loss 0.4312436481316884
# Epoch #1/100 ended: mean_train_loss=0.4827, running_train_acc=0.7933, mean_val_loss=0.4312, running_val_acc=0.8451
# epoch 2: saved model with loss 0.41266388694445294
# Epoch #2/100 ended: mean_train_loss=0.4525, running_train_acc=0.8109, mean_val_loss=0.4127, running_val_acc=0.8592
# Epoch #3/100 ended: mean_train_loss=0.4579, running_train_acc=0.8144, mean_val_loss=0.4204, running_val_acc=0.8239
# epoch 4: saved model with loss 0.40640661782688564
# Epoch #4/100 ended: mean_train_loss=0.4614, running_train_acc=0.8004, mean_val_loss=0.4064, running_val_acc=0.8732
# Epoch #5/100 ended: mean_train_loss=0.4618, running_train_acc=0.7933, mean_val_loss=0.4193, running_val_acc=0.8662
# epoch 6: saved model with loss 0.39586038059658474
# Epoch #6/100 ended: mean_train_loss=0.4338, running_train_acc=0.8074, mean_val_loss=0.3959, running_val_acc=0.8662
# epoch 7: saved model with loss 0.39120779434839886
# Epoch #7/100 ended: mean_train_loss=0.4383, running_train_acc=0.8126, mean_val_loss=0.3912, running_val_acc=0.8803
# Epoch #8/100 ended: mean_train_loss=0.4206, running_train_acc=0.8144, mean_val_loss=0.4131, running_val_acc=0.8521
# Epoch #9/100 ended: mean_train_loss=0.4317, running_train_acc=0.8266, mean_val_loss=0.4051, running_val_acc=0.8592
# Epoch #10/100 ended: mean_train_loss=0.4333, running_train_acc=0.8179, mean_val_loss=0.3996, running_val_acc=0.8451
# Epoch #11/100 ended: mean_train_loss=0.4189, running_train_acc=0.8196, mean_val_loss=0.4042, running_val_acc=0.8662
# Epoch #12/100 ended: mean_train_loss=0.4502, running_train_acc=0.8126, mean_val_loss=0.3935, running_val_acc=0.8732
# Epoch #13/100 ended: mean_train_loss=0.4320, running_train_acc=0.8056, mean_val_loss=0.4025, running_val_acc=0.8451
# Epoch #14/100 ended: mean_train_loss=0.4130, running_train_acc=0.8546, mean_val_loss=0.4081, running_val_acc=0.8380
# Epoch #15/100 ended: mean_train_loss=0.4226, running_train_acc=0.8284, mean_val_loss=0.4003, running_val_acc=0.8662
# Epoch #16/100 ended: mean_train_loss=0.4134, running_train_acc=0.8301, mean_val_loss=0.4058, running_val_acc=0.8380
# Epoch #17/100 ended: mean_train_loss=0.4188, running_train_acc=0.8126, mean_val_loss=0.4080, running_val_acc=0.8380
# Breaking on epoch 17; loaded best loss model from file
# Fold 2/5 accuracy: 0.8202
# Epoch #0/100 ended: mean_train_loss=0.5903, running_train_acc=0.6830, mean_val_loss=0.4610, running_val_acc=0.7746
# epoch 1: saved model with loss 0.4205661250485314
# Epoch #1/100 ended: mean_train_loss=0.4628, running_train_acc=0.7968, mean_val_loss=0.4206, running_val_acc=0.8521
# Epoch #2/100 ended: mean_train_loss=0.4429, running_train_acc=0.7881, mean_val_loss=0.4262, running_val_acc=0.8099
# Epoch #3/100 ended: mean_train_loss=0.4471, running_train_acc=0.8021, mean_val_loss=0.4244, running_val_acc=0.8451
# Epoch #4/100 ended: mean_train_loss=0.4383, running_train_acc=0.8214, mean_val_loss=0.4331, running_val_acc=0.8310
# Epoch #5/100 ended: mean_train_loss=0.4375, running_train_acc=0.8144, mean_val_loss=0.4283, running_val_acc=0.8310
# epoch 6: saved model with loss 0.4194006522496541
# Epoch #6/100 ended: mean_train_loss=0.4245, running_train_acc=0.8179, mean_val_loss=0.4194, running_val_acc=0.8451
# Epoch #7/100 ended: mean_train_loss=0.4447, running_train_acc=0.8091, mean_val_loss=0.4232, running_val_acc=0.8310
# Epoch #8/100 ended: mean_train_loss=0.3993, running_train_acc=0.8406, mean_val_loss=0.4214, running_val_acc=0.8310
# Epoch #9/100 ended: mean_train_loss=0.4120, running_train_acc=0.8231, mean_val_loss=0.4339, running_val_acc=0.8451
# Epoch #10/100 ended: mean_train_loss=0.4152, running_train_acc=0.8249, mean_val_loss=0.4217, running_val_acc=0.8380
# Epoch #11/100 ended: mean_train_loss=0.4302, running_train_acc=0.8109, mean_val_loss=0.4240, running_val_acc=0.8310
# epoch 12: saved model with loss 0.40218273798624676
# Epoch #12/100 ended: mean_train_loss=0.4242, running_train_acc=0.8284, mean_val_loss=0.4022, running_val_acc=0.8310
# Epoch #13/100 ended: mean_train_loss=0.4107, running_train_acc=0.8406, mean_val_loss=0.4211, running_val_acc=0.8239
# Epoch #14/100 ended: mean_train_loss=0.4220, running_train_acc=0.8284, mean_val_loss=0.4123, running_val_acc=0.8380
# Epoch #15/100 ended: mean_train_loss=0.4310, running_train_acc=0.8354, mean_val_loss=0.4303, running_val_acc=0.8310
# Epoch #16/100 ended: mean_train_loss=0.4027, running_train_acc=0.8354, mean_val_loss=0.4204, running_val_acc=0.8239
# Epoch #17/100 ended: mean_train_loss=0.4266, running_train_acc=0.8109, mean_val_loss=0.4212, running_val_acc=0.8169
# Epoch #18/100 ended: mean_train_loss=0.4247, running_train_acc=0.8389, mean_val_loss=0.4215, running_val_acc=0.8380
# Epoch #19/100 ended: mean_train_loss=0.4091, running_train_acc=0.8249, mean_val_loss=0.4230, running_val_acc=0.8310
# Epoch #20/100 ended: mean_train_loss=0.3947, running_train_acc=0.8494, mean_val_loss=0.4184, running_val_acc=0.8380
# Epoch #21/100 ended: mean_train_loss=0.3846, running_train_acc=0.8441, mean_val_loss=0.4248, running_val_acc=0.8380
# Epoch #22/100 ended: mean_train_loss=0.3993, running_train_acc=0.8301, mean_val_loss=0.4173, running_val_acc=0.8380
# Breaking on epoch 22; loaded best loss model from file
# Fold 3/5 accuracy: 0.7921
# Epoch #0/100 ended: mean_train_loss=0.5554, running_train_acc=0.7373, mean_val_loss=0.4768, running_val_acc=0.8099
# epoch 1: saved model with loss 0.43567001322905224
# Epoch #1/100 ended: mean_train_loss=0.4681, running_train_acc=0.7986, mean_val_loss=0.4357, running_val_acc=0.8169
# Epoch #2/100 ended: mean_train_loss=0.4540, running_train_acc=0.7881, mean_val_loss=0.4526, running_val_acc=0.8099
# Epoch #3/100 ended: mean_train_loss=0.4528, running_train_acc=0.8039, mean_val_loss=0.4420, running_val_acc=0.8169
# Epoch #4/100 ended: mean_train_loss=0.4365, running_train_acc=0.8249, mean_val_loss=0.4425, running_val_acc=0.8239
# Epoch #5/100 ended: mean_train_loss=0.4447, running_train_acc=0.8039, mean_val_loss=0.4468, running_val_acc=0.8169
# Epoch #6/100 ended: mean_train_loss=0.4230, running_train_acc=0.8284, mean_val_loss=0.4476, running_val_acc=0.8028
# Epoch #7/100 ended: mean_train_loss=0.4269, running_train_acc=0.8266, mean_val_loss=0.4523, running_val_acc=0.7958
# Epoch #8/100 ended: mean_train_loss=0.4131, running_train_acc=0.8284, mean_val_loss=0.4511, running_val_acc=0.8239
# Epoch #9/100 ended: mean_train_loss=0.4019, running_train_acc=0.8266, mean_val_loss=0.4542, running_val_acc=0.8028
# Epoch #10/100 ended: mean_train_loss=0.4304, running_train_acc=0.8091, mean_val_loss=0.4530, running_val_acc=0.8099
# Epoch #11/100 ended: mean_train_loss=0.4211, running_train_acc=0.8249, mean_val_loss=0.4501, running_val_acc=0.8099
# Breaking on epoch 11; loaded best loss model from file
# Fold 4/5 accuracy: 0.8315
# Epoch #0/100 ended: mean_train_loss=0.5450, running_train_acc=0.7443, mean_val_loss=0.4830, running_val_acc=0.8028
# epoch 1: saved model with loss 0.4529789454407162
# Epoch #1/100 ended: mean_train_loss=0.4987, running_train_acc=0.7881, mean_val_loss=0.4530, running_val_acc=0.8380
# epoch 2: saved model with loss 0.4468507369359334
# Epoch #2/100 ended: mean_train_loss=0.4732, running_train_acc=0.7758, mean_val_loss=0.4469, running_val_acc=0.8239
# epoch 3: saved model with loss 0.4387016064590878
# Epoch #3/100 ended: mean_train_loss=0.4628, running_train_acc=0.7986, mean_val_loss=0.4387, running_val_acc=0.8099
# Epoch #4/100 ended: mean_train_loss=0.4591, running_train_acc=0.8021, mean_val_loss=0.4428, running_val_acc=0.8310
# Epoch #5/100 ended: mean_train_loss=0.4164, running_train_acc=0.8179, mean_val_loss=0.4478, running_val_acc=0.8380
# Epoch #6/100 ended: mean_train_loss=0.4297, running_train_acc=0.8144, mean_val_loss=0.4413, running_val_acc=0.8310
# Epoch #7/100 ended: mean_train_loss=0.4721, running_train_acc=0.7933, mean_val_loss=0.4422, running_val_acc=0.8380
# Epoch #8/100 ended: mean_train_loss=0.4219, running_train_acc=0.8231, mean_val_loss=0.4401, running_val_acc=0.8310
# Epoch #9/100 ended: mean_train_loss=0.4183, running_train_acc=0.8126, mean_val_loss=0.4435, running_val_acc=0.8169
# Epoch #10/100 ended: mean_train_loss=0.4117, running_train_acc=0.8336, mean_val_loss=0.4463, running_val_acc=0.8310
# Epoch #11/100 ended: mean_train_loss=0.4303, running_train_acc=0.8214, mean_val_loss=0.4398, running_val_acc=0.8169
# Epoch #12/100 ended: mean_train_loss=0.4155, running_train_acc=0.8319, mean_val_loss=0.4445, running_val_acc=0.8169
# Epoch #13/100 ended: mean_train_loss=0.4320, running_train_acc=0.8091, mean_val_loss=0.4432, running_val_acc=0.8239
# Breaking on epoch 13; loaded best loss model from file
# Fold 5/5 accuracy: 0.8483
# -> Best fold: 5, CV accuracy: 0.8160, std: 0.0231

# %%
pipeline.predict()
# Out:
# Best step is 4.random_forest with None
# Predictions saved to csv

# %% [markdown]
# ### Логистическая регрессия
#
# Посмотрим, как влияет коэффициент L1 регуляризации на метрику. Видимо, влияние малое
#
# Для параметров ("l1_ratio": 0, "solver": "lbfgs", "max_iter": 500)
#
# - Лучший фолд: 0.8315
# - Public LB: 0.76794

# %%
config_elastic = config.copy()

to_train = []

for i in range(0, 10):
    to_train.append(
        {
            "model": "linear",
            "params": {"l1_ratio": i * 0.1, "solver": "saga", "max_iter": 2000},
        }
    )

config_elastic.experiment.to_train = to_train
config_elastic.experiment.prediction.fold_strategy = "vote"

elastic_pipeline = ClassificationPipeline(config_elastic)

elastic_pipeline.run()
# Out:
# {'model': 'linear', 'params': {'l1_ratio': 0.0, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (0): linear с {'l1_ratio': 0.0, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7933
# Фолд 2/5 accuracy: 0.8090
# Фолд 3/5 accuracy: 0.7921
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8258
# -> Лучший фолд: 5, CV accuracy: 0.8070, std: 0.0129
#
# {'model': 'linear', 'params': {'l1_ratio': 0.1, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (1): linear с {'l1_ratio': 0.1, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7933
# Фолд 2/5 accuracy: 0.8090
# Фолд 3/5 accuracy: 0.7921
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8258
# -> Лучший фолд: 5, CV accuracy: 0.8070, std: 0.0129
#
# {'model': 'linear', 'params': {'l1_ratio': 0.2, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (2): linear с {'l1_ratio': 0.2, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7933
# Фолд 2/5 accuracy: 0.8090
# Фолд 3/5 accuracy: 0.7921
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8258
# -> Лучший фолд: 5, CV accuracy: 0.8070, std: 0.0129
#
# {'model': 'linear', 'params': {'l1_ratio': 0.30000000000000004, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (3): linear с {'l1_ratio': 0.30000000000000004, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7933
# Фолд 2/5 accuracy: 0.8090
# Фолд 3/5 accuracy: 0.7921
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8258
# -> Лучший фолд: 5, CV accuracy: 0.8070, std: 0.0129
#
# {'model': 'linear', 'params': {'l1_ratio': 0.4, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (4): linear с {'l1_ratio': 0.4, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7933
# Фолд 2/5 accuracy: 0.8146
# Фолд 3/5 accuracy: 0.7921
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8202
# -> Лучший фолд: 5, CV accuracy: 0.8070, std: 0.0118
#
# {'model': 'linear', 'params': {'l1_ratio': 0.5, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (5): linear с {'l1_ratio': 0.5, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7877
# Фолд 2/5 accuracy: 0.8146
# Фолд 3/5 accuracy: 0.7921
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8258
# -> Лучший фолд: 5, CV accuracy: 0.8070, std: 0.0146
#
# {'model': 'linear', 'params': {'l1_ratio': 0.6000000000000001, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (6): linear с {'l1_ratio': 0.6000000000000001, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7877
# Фолд 2/5 accuracy: 0.8146
# Фолд 3/5 accuracy: 0.7921
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8258
# -> Лучший фолд: 5, CV accuracy: 0.8070, std: 0.0146
#
# {'model': 'linear', 'params': {'l1_ratio': 0.7000000000000001, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (7): linear с {'l1_ratio': 0.7000000000000001, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7877
# Фолд 2/5 accuracy: 0.8146
# Фолд 3/5 accuracy: 0.7978
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8258
# -> Лучший фолд: 5, CV accuracy: 0.8081, std: 0.0136
#
# {'model': 'linear', 'params': {'l1_ratio': 0.8, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (8): linear с {'l1_ratio': 0.8, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7877
# Фолд 2/5 accuracy: 0.8146
# Фолд 3/5 accuracy: 0.7978
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8258
# -> Лучший фолд: 5, CV accuracy: 0.8081, std: 0.0136
#
# {'model': 'linear', 'params': {'l1_ratio': 0.9, 'solver': 'saga', 'max_iter': 2000}}
# Шаг (9): linear с {'l1_ratio': 0.9, 'solver': 'saga', 'max_iter': 2000}
# Фолд 1/5 accuracy: 0.7877
# Фолд 2/5 accuracy: 0.8146
# Фолд 3/5 accuracy: 0.7978
# Фолд 4/5 accuracy: 0.8146
# Фолд 5/5 accuracy: 0.8258
# -> Лучший фолд: 5, CV accuracy: 0.8081, std: 0.0136

# %%
boxplot(elastic_pipeline.results)

# %%
elastic_pipeline.predict()
# Out:
# Лучший шаг: 9.logistic_regression с {'l1_ratio': 0.9, 'solver': 'saga', 'max_iter': 2000}
# Предсказания сохранены в csv

# %% [markdown]
# ### KNN
#
# Посмотрим, как меняется метрика в зависимости от количества соседей (k)
#
# По графику вроде бы лучшее кол-во соседей = 7
#
# - Лучший фолд (k=7): 0.8315
# - Public LB (k=7): 0.74162

# %%
config_knn = config.copy()

to_train = []

for i in range(1, 10):
    to_train.append(
        {
            "model": "knn",
            "params": {"n_neighbors": i},
        }
    )

config_knn.experiment.to_train = to_train

pipeline_knn = ClassificationPipeline(config_knn)

pipeline_knn.run()
# Out:
# Running (0): knn with {'n_neighbors': 1}
# Fold 1/5 accuracy: 0.7039
# Fold 2/5 accuracy: 0.7135
# Fold 3/5 accuracy: 0.7247
# Fold 4/5 accuracy: 0.7640
# Fold 5/5 accuracy: 0.7753
# -> Best fold: 5, CV accuracy: 0.7363, std: 0.0283
#
# Running (1): knn with {'n_neighbors': 2}
# Fold 1/5 accuracy: 0.7654
# Fold 2/5 accuracy: 0.7697
# Fold 3/5 accuracy: 0.7303
# Fold 4/5 accuracy: 0.7472
# Fold 5/5 accuracy: 0.7360
# -> Best fold: 2, CV accuracy: 0.7497, std: 0.0156
#
# Running (2): knn with {'n_neighbors': 3}
# Fold 1/5 accuracy: 0.8380
# Fold 2/5 accuracy: 0.6629
# Fold 3/5 accuracy: 0.7303
# Fold 4/5 accuracy: 0.7978
# Fold 5/5 accuracy: 0.7584
# -> Best fold: 1, CV accuracy: 0.7575, std: 0.0596
#
# Running (3): knn with {'n_neighbors': 4}
# Fold 1/5 accuracy: 0.8101
# Fold 2/5 accuracy: 0.7921
# Fold 3/5 accuracy: 0.7472
# Fold 4/5 accuracy: 0.8090
# Fold 5/5 accuracy: 0.7528
# -> Best fold: 1, CV accuracy: 0.7822, std: 0.0271
#
# Running (4): knn with {'n_neighbors': 5}
# Fold 1/5 accuracy: 0.7989
# Fold 2/5 accuracy: 0.8034
# Fold 3/5 accuracy: 0.7584
# Fold 4/5 accuracy: 0.8146
# Fold 5/5 accuracy: 0.7584
# -> Best fold: 4, CV accuracy: 0.7867, std: 0.0237
#
# Running (5): knn with {'n_neighbors': 6}
# Fold 1/5 accuracy: 0.7654
# Fold 2/5 accuracy: 0.8034
# Fold 3/5 accuracy: 0.7809
# Fold 4/5 accuracy: 0.8090
# Fold 5/5 accuracy: 0.7921
# -> Best fold: 4, CV accuracy: 0.7902, std: 0.0157
#
# Running (6): knn with {'n_neighbors': 7}
# Fold 1/5 accuracy: 0.8045
# Fold 2/5 accuracy: 0.8090
# Fold 3/5 accuracy: 0.7865
# Fold 4/5 accuracy: 0.7978
# Fold 5/5 accuracy: 0.7921
# -> Best fold: 2, CV accuracy: 0.7980, std: 0.0081
#
# Running (7): knn with {'n_neighbors': 8}
# Fold 1/5 accuracy: 0.7709
# Fold 2/5 accuracy: 0.8090
# Fold 3/5 accuracy: 0.7865
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8034
# -> Best fold: 2, CV accuracy: 0.7946, std: 0.0140
#
# Running (8): knn with {'n_neighbors': 9}
# Fold 1/5 accuracy: 0.7821
# Fold 2/5 accuracy: 0.8146
# Fold 3/5 accuracy: 0.7865
# Fold 4/5 accuracy: 0.8090
# Fold 5/5 accuracy: 0.8034
# -> Best fold: 2, CV accuracy: 0.7991, std: 0.0127

# %%
boxplot(pipeline_knn.results)

# %% [markdown]
# ### Дерево
#
# Посмотрим, можно ли регуляризовывать дерево минимальным кол-вом объектов в листе
#
# (мин. 4 объекта в листе)
# - Лучший фолд: 0.8371
# - Public LB: 0.75837
#
# Хуже, чем логрег: Возможно, дерево переобучилось на трейне

# %%
config_tree = config.copy()

to_train = []

for i in range(1, 8):
    to_train.append(
        {
            "model": "decision_tree",
            "params": {"min_samples_leaf": i},
        }
    )

config_tree.experiment.to_train = to_train

pipeline_tree = ClassificationPipeline(config_tree)

pipeline_tree.run()
# Out:
# Running (0): decision_tree with {'random_state': 42, 'min_samples_leaf': 1}
# Fold 1/5 accuracy: 0.7821
# Fold 2/5 accuracy: 0.7472
# Fold 3/5 accuracy: 0.7472
# Fold 4/5 accuracy: 0.7528
# Fold 5/5 accuracy: 0.7584
# -> Best fold: 1, CV accuracy: 0.7575, std: 0.0130
#
# Running (1): decision_tree with {'random_state': 42, 'min_samples_leaf': 2}
# Fold 1/5 accuracy: 0.8156
# Fold 2/5 accuracy: 0.7022
# Fold 3/5 accuracy: 0.7472
# Fold 4/5 accuracy: 0.7584
# Fold 5/5 accuracy: 0.8034
# -> Best fold: 1, CV accuracy: 0.7654, std: 0.0408
#
# Running (2): decision_tree with {'random_state': 42, 'min_samples_leaf': 3}
# Fold 1/5 accuracy: 0.8380
# Fold 2/5 accuracy: 0.7472
# Fold 3/5 accuracy: 0.7528
# Fold 4/5 accuracy: 0.7865
# Fold 5/5 accuracy: 0.7809
# -> Best fold: 1, CV accuracy: 0.7811, std: 0.0323
#
# Running (3): decision_tree with {'random_state': 42, 'min_samples_leaf': 4}
# Fold 1/5 accuracy: 0.8324
# Fold 2/5 accuracy: 0.7472
# Fold 3/5 accuracy: 0.8090
# Fold 4/5 accuracy: 0.7809
# Fold 5/5 accuracy: 0.7865
# -> Best fold: 1, CV accuracy: 0.7912, std: 0.0286
#
# Running (4): decision_tree with {'random_state': 42, 'min_samples_leaf': 5}
# Fold 1/5 accuracy: 0.8324
# Fold 2/5 accuracy: 0.7584
# Fold 3/5 accuracy: 0.8034
# Fold 4/5 accuracy: 0.7921
# Fold 5/5 accuracy: 0.7978
# -> Best fold: 1, CV accuracy: 0.7968, std: 0.0237
#
# Running (5): decision_tree with {'random_state': 42, 'min_samples_leaf': 6}
# Fold 1/5 accuracy: 0.8268
# Fold 2/5 accuracy: 0.7584
# Fold 3/5 accuracy: 0.7865
# Fold 4/5 accuracy: 0.7921
# Fold 5/5 accuracy: 0.7978
# -> Best fold: 1, CV accuracy: 0.7923, std: 0.0219
#
# Running (6): decision_tree with {'random_state': 42, 'min_samples_leaf': 7}
# Fold 1/5 accuracy: 0.7933
# Fold 2/5 accuracy: 0.7697
# Fold 3/5 accuracy: 0.7865
# Fold 4/5 accuracy: 0.8315
# Fold 5/5 accuracy: 0.7978
# -> Best fold: 4, CV accuracy: 0.7957, std: 0.0203

# %%
boxplot(pipeline_tree.results)

# %% [markdown]
# ### Случайный лес
#
# Посмотрим, зависит ли метрика от кол-ва деревьев
#
# 700 деревьев
# - Лучший фолд: 0.8371
# - Public LB: 0.79186
#
# ----
# Вернулся после регрессии и понял, что здесь глубина 3, а с глубиной побольше результаты могут и улучшиться

# %%
config_rf = config.copy()

to_train = []

for i in range(1, 8):
    to_train.append(
        {
            "model": "random_forest",
            "params": {"n_estimators": i * 100},
        }
    )


config_rf.experiment.to_train = to_train

pipeline_rf = ClassificationPipeline(config_rf)

pipeline_rf.run()
# Out:
# Running (0): random_forest with {'n_estimators': 100, 'max_depth': 3, 'random_state': 42}
# Fold 1/5 accuracy: 0.8156
# Fold 2/5 accuracy: 0.7921
# Fold 3/5 accuracy: 0.8034
# Fold 4/5 accuracy: 0.8146
# Fold 5/5 accuracy: 0.8427
# -> Best fold: 5, CV accuracy: 0.8137, std: 0.0168
#
# Running (1): random_forest with {'n_estimators': 200, 'max_depth': 3, 'random_state': 42}
# Fold 1/5 accuracy: 0.8324
# Fold 2/5 accuracy: 0.8090
# Fold 3/5 accuracy: 0.8034
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8371
# -> Best fold: 5, CV accuracy: 0.8170, std: 0.0147
#
# Running (2): random_forest with {'n_estimators': 300, 'max_depth': 3, 'random_state': 42}
# Fold 1/5 accuracy: 0.8268
# Fold 2/5 accuracy: 0.8090
# Fold 3/5 accuracy: 0.7978
# Fold 4/5 accuracy: 0.8090
# Fold 5/5 accuracy: 0.8427
# -> Best fold: 5, CV accuracy: 0.8170, std: 0.0158
#
# Running (3): random_forest with {'n_estimators': 400, 'max_depth': 3, 'random_state': 42}
# Fold 1/5 accuracy: 0.8268
# Fold 2/5 accuracy: 0.8090
# Fold 3/5 accuracy: 0.7978
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8483
# -> Best fold: 5, CV accuracy: 0.8170, std: 0.0184
#
# Running (4): random_forest with {'n_estimators': 500, 'max_depth': 3, 'random_state': 42}
# Fold 1/5 accuracy: 0.8268
# Fold 2/5 accuracy: 0.8146
# Fold 3/5 accuracy: 0.7921
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8483
# -> Best fold: 5, CV accuracy: 0.8170, std: 0.0194
#
# Running (5): random_forest with {'n_estimators': 600, 'max_depth': 3, 'random_state': 42}
# Fold 1/5 accuracy: 0.8268
# Fold 2/5 accuracy: 0.8090
# Fold 3/5 accuracy: 0.7921
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8539
# -> Best fold: 5, CV accuracy: 0.8170, std: 0.0216
#
# Running (6): random_forest with {'n_estimators': 700, 'max_depth': 3, 'random_state': 42}
# Fold 1/5 accuracy: 0.8268
# Fold 2/5 accuracy: 0.8146
# Fold 3/5 accuracy: 0.7921
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8539
# -> Best fold: 5, CV accuracy: 0.8182, std: 0.0213

# %%
boxplot(pipeline_rf.results)

# %% [markdown]
# ### Бустинг
#
# Посмотрим на кол-во итераций: почему-то самая большая метрика получается для 100 деревьев
#
# 100 деревьев
# - Лучший фолд: 0.8258
# - Public LB: 0.78708
#
# 1000 деревьев
# - Лучший фолд: 0.8268
# - Public LB: 0.76315
#
# 2000 деревьев
# - Лучший фолд: 0.8202
# - Public LB: 0.73205
#
# Переобучение? Или при дальнейшем обучении нужно больше уменьшать learning rate?

# %%
config_cat = config.copy()

to_train = []

iteration_counts = [*[i * 100 for i in range(1, 8)], 1000, 2000]

for ic in iteration_counts:
    to_train.append(
        {
            "model": "catboost",
            "params": {"iterations": ic},
        }
    )


config_cat.experiment.to_train = to_train

pipeline_cat = ClassificationPipeline(config_cat)

pipeline_cat.run()
# Out:
# Running (0): catboost with {'iterations': 100, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8324
# Fold 2/5 accuracy: 0.8034
# Fold 3/5 accuracy: 0.8090
# Fold 4/5 accuracy: 0.8258
# Fold 5/5 accuracy: 0.8315
# -> Best fold: 1, CV accuracy: 0.8204, std: 0.0120
#
# Running (1): catboost with {'iterations': 200, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.7989
# Fold 2/5 accuracy: 0.8202
# Fold 3/5 accuracy: 0.7978
# Fold 4/5 accuracy: 0.8315
# Fold 5/5 accuracy: 0.7921
# -> Best fold: 4, CV accuracy: 0.8081, std: 0.0151
#
# Running (2): catboost with {'iterations': 300, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8101
# Fold 2/5 accuracy: 0.8258
# Fold 3/5 accuracy: 0.7978
# Fold 4/5 accuracy: 0.8258
# Fold 5/5 accuracy: 0.7753
# -> Best fold: 2, CV accuracy: 0.8070, std: 0.0190
#
# Running (3): catboost with {'iterations': 400, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8045
# Fold 2/5 accuracy: 0.8146
# Fold 3/5 accuracy: 0.7865
# Fold 4/5 accuracy: 0.8146
# Fold 5/5 accuracy: 0.7697
# -> Best fold: 2, CV accuracy: 0.7980, std: 0.0175
#
# Running (4): catboost with {'iterations': 500, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8156
# Fold 2/5 accuracy: 0.8034
# Fold 3/5 accuracy: 0.7809
# Fold 4/5 accuracy: 0.8315
# Fold 5/5 accuracy: 0.7809
# -> Best fold: 4, CV accuracy: 0.8025, std: 0.0197
#
# Running (5): catboost with {'iterations': 600, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8380
# Fold 2/5 accuracy: 0.8258
# Fold 3/5 accuracy: 0.7640
# Fold 4/5 accuracy: 0.8371
# Fold 5/5 accuracy: 0.7753
# -> Best fold: 1, CV accuracy: 0.8080, std: 0.0318
#
# Running (6): catboost with {'iterations': 700, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8324
# Fold 2/5 accuracy: 0.8202
# Fold 3/5 accuracy: 0.7584
# Fold 4/5 accuracy: 0.8146
# Fold 5/5 accuracy: 0.7584
# -> Best fold: 1, CV accuracy: 0.7968, std: 0.0319
#
# Running (7): catboost with {'iterations': 1000, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8268
# Fold 2/5 accuracy: 0.8258
# Fold 3/5 accuracy: 0.7697
# Fold 4/5 accuracy: 0.8258
# Fold 5/5 accuracy: 0.7753
# -> Best fold: 1, CV accuracy: 0.8047, std: 0.0264
#
# Running (8): catboost with {'iterations': 2000, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8156
# Fold 2/5 accuracy: 0.8146
# Fold 3/5 accuracy: 0.7416
# Fold 4/5 accuracy: 0.8146
# Fold 5/5 accuracy: 0.7697
# -> Best fold: 1, CV accuracy: 0.7912, std: 0.0304

# %%
boxplot(pipeline_cat.results, iteration_counts)

# %%
config_cat = config.copy()

to_train = []

# for i in range(1, 8):
to_train.append(
    {
        "model": "catboost",
        "params": {"iterations": 1000},
    }
)


config_cat.experiment.to_train = to_train

pipeline_cat = ClassificationPipeline(config_cat)

pipeline_cat.run()
# Out:
# Running (0): catboost with {'iterations': 1000, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8268
# Fold 2/5 accuracy: 0.8258
# Fold 3/5 accuracy: 0.7697
# Fold 4/5 accuracy: 0.8258
# Fold 5/5 accuracy: 0.7753
# -> Best fold: 1, CV accuracy: 0.8047, std: 0.0264

# %%
pipeline_cat.predict()
# Out:
# Best step is 0.catboost with {'iterations': 1000}
# Predictions saved to csv

# %% [markdown]
# ### LightGBM
#
# Гораздо быстрее, чем CatBoost
#
# Для 300 деревьев:
# - Лучший фолд: 0.8258
# - Public LB: 0.76794

# %%
config_l = config.copy()

to_train = []

n_estimators = [*[i * 100 for i in range(1, 8)], 1000, 2000]

for n in n_estimators:
    to_train.append(
        {
            "model": "lightgbm",
            "params": {"n_estimators": n},
        }
    )

config_l.experiment.to_train = to_train

config_l.split.n_folds = 2

pipeline_l = ClassificationPipeline(config_l)

pipeline_l.run()
# Out:
# Running (0): lightgbm with {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/2 accuracy: 0.8004
# Fold 2/2 accuracy: 0.8225
# -> Best fold: 2, CV accuracy: 0.8115, std: 0.0110
#
# Running (1): lightgbm with {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/2 accuracy: 0.8027
# Fold 2/2 accuracy: 0.8202
# -> Best fold: 2, CV accuracy: 0.8115, std: 0.0088
#
# Running (2): lightgbm with {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/2 accuracy: 0.7870
# Fold 2/2 accuracy: 0.8090
# -> Best fold: 2, CV accuracy: 0.7980, std: 0.0110
#
# Running (3): lightgbm with {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/2 accuracy: 0.7870
# Fold 2/2 accuracy: 0.8022
# -> Best fold: 2, CV accuracy: 0.7946, std: 0.0076
#
# Running (4): lightgbm with {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/2 accuracy: 0.7892
# Fold 2/2 accuracy: 0.7888
# -> Best fold: 1, CV accuracy: 0.7890, std: 0.0002
#
# Running (5): lightgbm with {'n_estimators': 600, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/2 accuracy: 0.7803
# Fold 2/2 accuracy: 0.7865
# -> Best fold: 2, CV accuracy: 0.7834, std: 0.0031
#
# Running (6): lightgbm with {'n_estimators': 700, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/2 accuracy: 0.7825
# Fold 2/2 accuracy: 0.7910
# -> Best fold: 2, CV accuracy: 0.7868, std: 0.0043
#
# Running (7): lightgbm with {'n_estimators': 1000, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/2 accuracy: 0.7780
# Fold 2/2 accuracy: 0.7730
# -> Best fold: 1, CV accuracy: 0.7755, std: 0.0025
#
# Running (8): lightgbm with {'n_estimators': 2000, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/2 accuracy: 0.7803
# Fold 2/2 accuracy: 0.7798
# -> Best fold: 1, CV accuracy: 0.7800, std: 0.0002

# %%
boxplot(pipeline_l.results, n_estimators)

# %%
pipeline_l.predict()
# Out:
# Best step is 0.lightgbm with {'n_estimators': 100}
# Predictions saved to csv

# %% [markdown]
# ### XGBoost
#
# Лучшая метрика для 300 деревьев
# - Лучший фолд: 0.8547
# - Public LB: 0.77033

# %%
config_xgb = config.copy()

to_train = []

n_estimators = [*[i * 100 for i in range(1, 8)], 1000, 2000]

for n in n_estimators:
    to_train.append(
        {
            "model": "xgboost",
            "params": {"n_estimators": n},
        }
    )

config_xgb.experiment.to_train = to_train

pipeline_xgb = ClassificationPipeline(config_xgb)

pipeline_xgb.run()
# Out:
# Running (0): xgboost with {'n_estimators': 100, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8436
# Fold 2/5 accuracy: 0.8034
# Fold 3/5 accuracy: 0.7753
# Fold 4/5 accuracy: 0.7865
# Fold 5/5 accuracy: 0.8202
# -> Best fold: 1, CV accuracy: 0.8058, std: 0.0243
#
# Running (1): xgboost with {'n_estimators': 200, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8436
# Fold 2/5 accuracy: 0.7865
# Fold 3/5 accuracy: 0.7865
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8090
# -> Best fold: 1, CV accuracy: 0.8058, std: 0.0209
#
# Running (2): xgboost with {'n_estimators': 300, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8380
# Fold 2/5 accuracy: 0.7865
# Fold 3/5 accuracy: 0.7584
# Fold 4/5 accuracy: 0.8034
# Fold 5/5 accuracy: 0.8034
# -> Best fold: 1, CV accuracy: 0.7979, std: 0.0259
#
# Running (3): xgboost with {'n_estimators': 400, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8436
# Fold 2/5 accuracy: 0.7865
# Fold 3/5 accuracy: 0.7528
# Fold 4/5 accuracy: 0.7921
# Fold 5/5 accuracy: 0.8034
# -> Best fold: 1, CV accuracy: 0.7957, std: 0.0293
#
# Running (4): xgboost with {'n_estimators': 500, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8436
# Fold 2/5 accuracy: 0.7865
# Fold 3/5 accuracy: 0.7472
# Fold 4/5 accuracy: 0.7978
# Fold 5/5 accuracy: 0.7921
# -> Best fold: 1, CV accuracy: 0.7934, std: 0.0307
#
# Running (5): xgboost with {'n_estimators': 600, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8436
# Fold 2/5 accuracy: 0.7809
# Fold 3/5 accuracy: 0.7472
# Fold 4/5 accuracy: 0.7978
# Fold 5/5 accuracy: 0.7921
# -> Best fold: 1, CV accuracy: 0.7923, std: 0.0311
#
# Running (6): xgboost with {'n_estimators': 700, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8436
# Fold 2/5 accuracy: 0.7753
# Fold 3/5 accuracy: 0.7528
# Fold 4/5 accuracy: 0.7978
# Fold 5/5 accuracy: 0.7865
# -> Best fold: 1, CV accuracy: 0.7912, std: 0.0301
#
# Running (7): xgboost with {'n_estimators': 1000, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8492
# Fold 2/5 accuracy: 0.7865
# Fold 3/5 accuracy: 0.7697
# Fold 4/5 accuracy: 0.7865
# Fold 5/5 accuracy: 0.7865
# -> Best fold: 1, CV accuracy: 0.7957, std: 0.0275
#
# Running (8): xgboost with {'n_estimators': 2000, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8492
# Fold 2/5 accuracy: 0.7809
# Fold 3/5 accuracy: 0.7640
# Fold 4/5 accuracy: 0.7753
# Fold 5/5 accuracy: 0.7697
# -> Best fold: 1, CV accuracy: 0.7878, std: 0.0312

# %%
boxplot(pipeline_xgb.results, n_estimators)

# %%
pipeline_xgb.predict()
# Out:
# Best step is 0.xgboost with {'n_estimators': 100}
# Predictions saved to csv

# %% [markdown]
# ### Модели на фичах с openFE
#
# Лучшая метрика
# - Лучший фолд:
# - Public LB:

# %%
config_dl = config.copy()

config_dl.general.experiment_name = "ensembles_ofe"

config_dl.paths.train = "data/train_openfe.csv"
config_dl.paths.test = "data/test_openfe.csv"

models = ["random_forest", "catboost", "lightgbm", "xgboost"]

for model in models:
    config_dl.models[model].preprocessing = "custom"

config_dl.experiment.to_train = [{"model": x} for x in models]

pipeline_dl = ClassificationPipeline(config_dl)

# %%
ofe_df = pd.read_csv(config_dl.paths.train, index_col="PassengerId")
ofe_test_df = pd.read_csv(config_dl.paths.test, index_col="PassengerId")
ofe_df.head()
# Out:
#              Pclass  Sex  SibSp  Parch  Family_Size  Alone  \
# PassengerId
# 1                 3    0      1      0            1      0
# 2                 1    1      1      0            1      0
# 3                 3    1      0      0            0      1
# 4                 1    1      1      0            1      0
# 5                 3    0      0      0            0      1
#
#              More_Than_4_relatives  Embarked_C  Embarked_S  Age_Group  ...  \
# PassengerId                                                            ...
# 1                                0         0.0         1.0          2  ...
# 2                                0         1.0         0.0          3  ...
# 3                                0         0.0         1.0          2  ...
# 4                                0         0.0         1.0          3  ...
# 5                                0         0.0         1.0          3  ...
#
#              autoFE_f_292  autoFE_f_293  autoFE_f_294  autoFE_f_295  \
# PassengerId
# 1                     1.0      0.722144           1.0      0.846373
# 2                     1.0      0.657895           1.0      0.846373
# 3                     1.0      0.333568           0.0      0.361858
# 4                     1.0      0.657895           1.0      0.846373
# 5                     1.0      0.333568           0.0      0.361858
#
#              autoFE_f_296  autoFE_f_297  autoFE_f_298  autoFE_f_299  \
# PassengerId
# 1                0.837485         359.0           2.0           3.0
# 2                0.920601         160.0           3.0           2.0
# 3                0.980687         557.0           2.0           4.0
# 4                0.051502         359.0           3.0           2.0
# 5                0.692764         557.0           3.0           3.0
#
#              autoFE_f_300  Survived
# PassengerId
# 1                0.420000         0
# 2                0.883721         1
# 3                0.420000         1
# 4                0.383721         1
# 5                0.383721         0
#
# [5 rows x 314 columns]

# %%
pipeline_dl.run()
# Out:
# Running (0): random_forest with {'n_estimators': 700, 'max_depth': 3, 'random_state': 42}
# Fold 1/5 accuracy: 0.8212
# Fold 2/5 accuracy: 0.7978
# Fold 3/5 accuracy: 0.8090
# Fold 4/5 accuracy: 0.8090
# Fold 5/5 accuracy: 0.8371
# -> Best fold: 5, CV accuracy: 0.8148, std: 0.0134
#
# Running (1): catboost with {'iterations': 300, 'depth': 6, 'cat_features': ['Sex', 'Pclass', 'SibSp', 'Parch', 'Alone', 'Age_Group', 'Fare_Range'], 'learning_rate': 0.1, 'random_state': 42, 'verbose': 0}
# Fold 1/5 accuracy: 0.8212
# Fold 2/5 accuracy: 0.8146
# Fold 3/5 accuracy: 0.8090
# Fold 4/5 accuracy: 0.8371
# Fold 5/5 accuracy: 0.7865
# -> Best fold: 4, CV accuracy: 0.8137, std: 0.0165
#
# Running (2): lightgbm with {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.1, 'random_state': 42, 'verbose': -1}
# Fold 1/5 accuracy: 0.8156
# Fold 2/5 accuracy: 0.8034
# Fold 3/5 accuracy: 0.7865
# Fold 4/5 accuracy: 0.8258
# Fold 5/5 accuracy: 0.7472
# -> Best fold: 4, CV accuracy: 0.7957, std: 0.0276
#
# Running (3): xgboost with {'n_estimators': 300, 'max_depth': 6, 'eval_metric': 'logloss', 'learning_rate': 0.1, 'random_state': 42}
# Fold 1/5 accuracy: 0.8436
# Fold 2/5 accuracy: 0.8090
# Fold 3/5 accuracy: 0.7978
# Fold 4/5 accuracy: 0.8315
# Fold 5/5 accuracy: 0.7472
# -> Best fold: 1, CV accuracy: 0.8058, std: 0.0335

# %%
config_dl.experiment.prediction.strategy = "each"
config_elastic.experiment.prediction.fold_strategy = "vote"
pipeline_dl.predict()
# Out:
# Predicting for each step...
# Predictions saved to csv

# %% [markdown]
# ### Deep Learning
#
# Модель со слоями [12, 128], [128, 64], [64, 2] с дропаутом 0.25:
# - Public LB (до сохранения и загрузки лучшего лосса): 0.79186
# - Public LB (после загрузки лучшего лосса): 0.78468

# %%
config_dl = config.copy()

config_dl.general.experiment_name = "dnn"
# config_dl.general.verbose = True

config_dl.experiment.to_train = [{"model": "dnn", "cv": False}]

pipeline_dl = ClassificationPipeline(config_dl)

# %%
pipeline_dl.run()
# Out:
# {'model': 'dnn', 'cv': False}
# Шаг (0): dnn с {'in_features': 12, 'hidden_sizes': [128, 64], 'out_features': 2, 'dropout_rate': 0.25, 'batch_size': 16, 'epochs': 100, 'learning_rate': 0.1, 'epochs_patience': 10, 'best_loss_threshold_to_save': 0.001, 'random_state': 42, 'save_dir': 'pytorch_models'}
# Данные валидации переданы в модель до fit
# Epoch #0/100 ended: mean_train_loss=0.6871, running_train_acc=0.7135, mean_val_loss=0.4638, running_val_acc=0.7821
# epoch 1: saved model with loss 0.45188434794545174
# Epoch #1/100 ended: mean_train_loss=0.5147, running_train_acc=0.7963, mean_val_loss=0.4519, running_val_acc=0.8045
# Epoch #2/100 ended: mean_train_loss=0.5408, running_train_acc=0.7697, mean_val_loss=0.5215, running_val_acc=0.7877
# Epoch #3/100 ended: mean_train_loss=0.5394, running_train_acc=0.7683, mean_val_loss=0.5713, running_val_acc=0.7207
# Epoch #4/100 ended: mean_train_loss=0.5001, running_train_acc=0.7935, mean_val_loss=0.4767, running_val_acc=0.7821
# Epoch #5/100 ended: mean_train_loss=0.5418, running_train_acc=0.7556, mean_val_loss=0.4625, running_val_acc=0.7765
# epoch 6: saved model with loss 0.43022771428028744
# Epoch #6/100 ended: mean_train_loss=0.5142, running_train_acc=0.7753, mean_val_loss=0.4302, running_val_acc=0.7933
# Epoch #7/100 ended: mean_train_loss=0.4971, running_train_acc=0.7963, mean_val_loss=0.4769, running_val_acc=0.8045
# epoch 8: saved model with loss 0.4267975774904092
# Epoch #8/100 ended: mean_train_loss=0.4892, running_train_acc=0.7935, mean_val_loss=0.4268, running_val_acc=0.8156
# Epoch #9/100 ended: mean_train_loss=0.4934, running_train_acc=0.7781, mean_val_loss=0.4437, running_val_acc=0.8324
# Epoch #10/100 ended: mean_train_loss=0.4961, running_train_acc=0.7823, mean_val_loss=0.4882, running_val_acc=0.8212
# Epoch #11/100 ended: mean_train_loss=0.4881, running_train_acc=0.7837, mean_val_loss=0.4616, running_val_acc=0.8045
# Epoch #12/100 ended: mean_train_loss=0.5272, running_train_acc=0.7739, mean_val_loss=0.5038, running_val_acc=0.8045
# Epoch #13/100 ended: mean_train_loss=0.4923, running_train_acc=0.7978, mean_val_loss=0.4786, running_val_acc=0.7933
# Epoch #14/100 ended: mean_train_loss=0.5044, running_train_acc=0.7795, mean_val_loss=0.4680, running_val_acc=0.7933
# Epoch #15/100 ended: mean_train_loss=0.4879, running_train_acc=0.7795, mean_val_loss=0.4371, running_val_acc=0.8156
# Epoch #16/100 ended: mean_train_loss=0.4808, running_train_acc=0.7893, mean_val_loss=0.4306, running_val_acc=0.8212
# Epoch #17/100 ended: mean_train_loss=0.4825, running_train_acc=0.7823, mean_val_loss=0.4395, running_val_acc=0.8212
# Epoch #18/100 ended: mean_train_loss=0.4543, running_train_acc=0.8118, mean_val_loss=0.4274, running_val_acc=0.8156
# Breaking on epoch 18; loaded best loss model from file
# Один сплит accuracy: 0.8156
# -> Лучший фолд: 1, CV accuracy: 0.8156, std: 0.0000

# %%
pipeline_dl.predict()
# Out:
# Best step is 0.dnn with None
# Predictions saved to csv
